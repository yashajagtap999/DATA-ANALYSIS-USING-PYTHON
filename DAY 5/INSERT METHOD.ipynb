# %%
#insert method:--d1.insert(pos,columnname,element)

# %%
# using insert method:--
import pandas as pd
d1=pd.DataFrame({"name":["YAsh","ashish","om","avi","prath"],
                 "salary":[100000,80000,50000,60000,30000],
                 "performance":[100,90,20,30,40],
                 "age":[24,20,30,40,38]})
print(d1)

d1.insert(4,"employee_id",[11,99,12,19,1])
print("updated value\n",d1)
# Out:
#      name  salary  performance  age
# 0    YAsh  100000          100   24
# 1  ashish   80000           90   20
# 2      om   50000           20   30
# 3     avi   60000           30   40
# 4   prath   30000           40   38
# updated value
#       name  salary  performance  age  employee_id
# 0    YAsh  100000          100   24           11
# 1  ashish   80000           90   20           99
# 2      om   50000           20   30           12
# 3     avi   60000           30   40           19
# 4   prath   30000           40   38            1
