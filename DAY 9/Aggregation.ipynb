# %%
# aggregation :-- summarize the data in mathematical terms
import pandas as pd
d1={"name":["YAsh","omkar","om","avi","prath"],
                 "salary":[100000,80000,90000,60000,30000],
                 "performance":[100,90,6,30,40],
                 "age":[24,27,30,40,38]}
df=pd.DataFrame(d1)
print(df)
print("mean of salary ")

d2=df["salary"].mean()
print(d2)
# Out:
#     name  salary  performance  age
# 0   YAsh  100000          100   24
# 1  omkar   80000           90   27
# 2     om   90000            6   30
# 3    avi   60000           30   40
# 4  prath   30000           40   38
# mean of salary
# 72000.0
