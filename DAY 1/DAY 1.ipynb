# %%
#Pandas:-- it is a powerful and popular python library used for dataanalysis and data manipualation developed in 2008

# %%
#To read the data from csv and excel:--
import pandas as pd
d1=pd.read_excel(r"C:\Users\YASH JAGTAP\Downloads\Training data.xlsx")
print(d1)
# Out:
#   College    Reviews      City Degree Admission
# 0    JSPM  Excellent      Pune     UG         Y
# 1     DPU       Poor      Pune     PG         N
# 2     PCU       Good     latur    PHD         Y
# 3    ADPU       Good  lohegaon     UG         Y
# 4     BVP       Poor    mumbai     PG         N

# %%
# To create csv file:--
import pandas as pd
d1={"Name":['ram','shyam','ghamshyam'],
    "Age":[10,20,21]
   }
df=pd.DataFrame(d1)
print(df)
df.to_csv("output.csv",index=False)
# Out:
#         Name  Age
# 0        ram   10
# 1      shyam   20
# 2  ghamshyam   21
